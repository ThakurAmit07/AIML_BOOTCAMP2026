# %% [markdown]
# <a href="https://colab.research.google.com/github/ThakurAmit07/AIML_BOOTCAMP2026/blob/main/Session_1GLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world how are you")
# Out:
# Hello world how are you

# %%
# BOOTCAMP ROADMAP

# All basics tools setup and singnup like-google colab,kaggle,github,chartgpt.
# All basics and question or doubts cleared regarding bootcamp(internship)
# How to use chatgpt effectively(in hackathons or,etc),
# How to use git and github(it's basics cleared).

# %%
print("""BOOTCAMP ROADMAP
.All basics tools setup and singnup like-google colab,kaggle,github,chartgpt.
.All basics and question or doubts cleared regarding bootcamp(internship)
.How to use chatgpt effectively(in hackathons or,etc),
.How to use git and github(it's basics cleared).""")
# Out:
# BOOTCAMP ROADMAP :-All basics tools setup and singnup like-google colab,kaggle,github,chartgpt.
# All basics and question or doubts cleared regarding bootcamp(internship)
# How to use chatgpt effectively(in hackathons or,etc),
# How to use git and github(it's basics cleared).
